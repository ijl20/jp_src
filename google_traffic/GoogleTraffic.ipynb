# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
capture = cv2.VideoCapture('cambridge_centre_2018-10-01.mp4')

frame_count = 0
while capture.isOpened():
    ret, frame = capture.read()
    if ret:
        frame_count += 1
        cv2.imshow('frame',frame)
    else:
        break
    if cv2.waitKey(100) & 0xFF == ord('q'):
        break
print( 'frames {0}'.format(frame_count))
# Out:
# frames 44

# %%
capture.release()
cv2.destroyAllWindows()

# %%
# cv2.imshow('Foo',frame)

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
src1 = cv2.imread('traffic1.png', 1)

# %%
plt.imshow(src1)

# %%
src2 = cv2.imread('traffic2.png', 1)

diff = cv2.subtract(src1, src2)

plt.imshow(diff)

# %%
cv2.imwrite('traffic_diff_5_mins.png', diff)
# Out:
# True
